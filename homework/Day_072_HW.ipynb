# %% [markdown]
# # 作業目標:

# %% [markdown]
# 寫出 ReLU & dReLU 一階導數
# 並列印

# %% [markdown]
# 作業重點
# Rectified Linear Unit- Relu

# %%
import numpy as np
from numpy import *
import matplotlib.pylab as plt
# %matplotlib inline

#ReLU
x =  np.arange(-10,10,0.01)
y=list(map(lambda x:x if x>0 else 0,x))
#ReLU函数图像
plt.plot(x,y)
plt.grid(color='b' , linewidth='0.1' ,linestyle='--')
#ReLU函数导数图像
dev_y =list(map(lambda x: 1 if x>0 else 0,x))
plt.plot(x,dev_y)
plt.grid(color='b' , linewidth='0.1' ,linestyle='--')
# Out:
# '\n作業:\n    寫出 ReLU & dReLU 一階導數\n    並列印\n'

# %%
#dReLU

x =  np.arange(-10,10,0.01)
lambda1=0.1   #指定lambda为0.1
y=list(map(lambda x:x if x>0 else lambda1*x,x))


#leaky ReLU函数图像
plt.plot(x,y)
plt.grid(color='b' , linewidth='0.1' ,linestyle='--')


#leaky ReLU函数导数图像
dev_y = list(map(lambda x: 1 if x>0 else lambda1,x))
plt.plot(x,dev_y)
plt.grid(color='b' , linewidth='0.1' ,linestyle='--')

# %%
#資料來源：https://zhuanlan.zhihu.com/p/39673127

'''
作業:
    寫出 ReLU & dReLU 一階導數
    並列印
'''
